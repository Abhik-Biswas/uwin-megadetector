# %%
# !pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.10.0.82-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.10.0.82-cp37-abi3-win_amd64.whl (38.8 MB)
# ...

# %%
import cv2

# %%
image = cv2.imread(r"\\vector.e3b.columbia.edu\e3b\Globus Database\UWIN Tagged Photos\batch_001\VID30155-00000.jpg")

# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/165.5 kB ? eta -:--:--
#      -------------- ------------------------ 61.4/165.5 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------- 165.5/165.5 kB 2.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.9 MB 15.9 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.1/7.9 MB 11.9 MB/s eta 0:00:01
#    --------- ------------------------------ 1.8/7.9 MB 11.4 MB/s eta 0:00:01
#    ------------ --------------------------- 2.5/7.9 MB 12.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.3/7.9 MB 13.9 MB/s eta 0:00:01
#    ------------------- -------------------- 4.0/7.9 MB 14.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.4/7.9 MB 14.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.5/7.9 MB 12.0 MB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
import os

# %%
image_list = os.listdir(r"\\vector.e3b.columbia.edu\e3b\Globus Database\UWIN Tagged Photos\batch_001")

# %%
image_list = [i for i in image_list if i.endswith(".jpg")]

# %%
image_list
# Out:
# ['VID30155-00000.jpg',
#  'VID30155-00001.jpg',
#  'VID30155-00002.jpg',
#  'VID30155-00003.jpg',
#  'VID30155-00004.jpg',
#  'VID30155-00005.jpg',
#  'VID30155-00006.jpg',
#  'VID30155-00007.jpg',
#  'VID30155-00008.jpg',
#  'VID30155-00009.jpg',
#  'VID30155-00010.jpg',
#  'VID30155-00011.jpg',
#  'VID30155-00012.jpg',
#  'VID30155-00013.jpg',
#  'VID30155-00014.jpg',
#  'VID30155-00015.jpg',
#  'VID30155-00016.jpg',
#  'VID30155-00017.jpg',
#  'VID30155-00018.jpg',
#  'VID30155-00019.jpg',
#  'VID30155-00020.jpg',
#  'VID30155-00021.jpg',
#  'VID30155-00022.jpg',
#  'VID30155-00023.jpg',
#  'VID30155-00024.jpg',
#  'VID30155-00025.jpg',
#  'VID30155-00026.jpg',
#  'VID30155-00027.jpg',
#  'VID30155-00028.jpg',
#  'VID30155-00029.jpg',
#  'VID30155-00030.jpg',
#  'VID30155-00031.jpg',
#  'VID30155-00032.jpg',
#  'VID30155-00033.jpg',
#  'VID30155-00034.jpg',
#  'VID30155-00035.jpg',
#  'VID30155-00036.jpg',
#  'VID30155-00037.jpg',
#  'VID30155-00038.jpg',
#  'VID30155-00039.jpg',
# ...

# %%
import tensorflow as tf

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.6 MB 7.3 MB/s eta 0:00:02
#    -- ------------------------------------- 0.8/11.6 MB 8.1 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.4/11.6 MB 10.8 MB/s eta 0:00:01
#    ------ --------------------------------- 2.0/11.6 MB 10.6 MB/s eta 0:00:01
#    --------- ------------------------------ 2.7/11.6 MB 11.5 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.4/11.6 MB 11.9 MB/s eta 0:00:01
#    ------------- -------------------------- 4.1/11.6 MB 12.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.8/11.6 MB 13.3 MB/s eta 0:00:01
#    ------------------- -------------------- 5.6/11.6 MB 13.7 MB/s eta 0:00:01
#    --------------------- ------------------ 6.3/11.6 MB 13.5 MB/s eta 0:00:01
#    ------------------------ --------------- 7.0/11.6 MB 13.6 MB/s eta 0:00:01
# ...

# %%
# !pip install numpy

# %%
# !pip install scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ---------------------------------------- 60.6/60.6 kB 1.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 15.0 MB/s eta 0:00:01
#    --- ------------------------------------ 1.1/11.0 MB 13.7 MB/s eta 0:00:01
#    ------ --------------------------------- 1.7/11.0 MB 12.0 MB/s eta 0:00:01
#    -------- ------------------------------- 2.4/11.0 MB 13.8 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.1/11.0 MB 14.1 MB/s eta 0:00:01
#    ------------- -------------------------- 3.8/11.0 MB 14.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.5/11.0 MB 14.4 MB/s eta 0:00:01
#    ------------------- -------------------- 5.2/11.0 MB 13.9 MB/s eta 0:00:01
#    --------------------- ------------------ 5.9/11.0 MB 14.6 MB/s eta 0:00:01
# ...
